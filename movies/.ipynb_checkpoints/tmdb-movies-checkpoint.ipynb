# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import

# %%
df = pd.read_csv("tmdb-movies.csv")
df.sample(3)
#pd.set_option('display.float_format', lamda x: '$.2f' %x) #day la ham hien ra 2 chu so thap phan
# Out:
#          id    imdb_id  popularity    budget    revenue  \
# 7418   4964  tt0478311    1.640237  30000000  219076518
# 8465  11238  tt0115491    1.841080         0          0
# 7911  15144  tt0088128    0.606839   6500000   23686027
#
#                        original_title  \
# 7418                       Knocked Up
# 8465  Aladdin and the King of Thieves
# 7911                  Sixteen Candles
#
#                                                    cast  \
# 7418  Seth Rogen|Katherine Heigl|Leslie Mann|Paul Ru...
# 8465  Scott Weinger|Linda Larkin|Robin Williams|John...
# 7911  Molly Ringwald|Justin Henry|Michael Schoefflin...
#
#                                                homepage     director  \
# 7418                         http://knockedupmovie.com/  Judd Apatow
# 8465  http://movies.disney.com/aladdin-and-the-king-...   Tad Stones
# 7911                                                NaN  John Hughes
#
#                                             tagline  ...  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %% [markdown]
# # Questions:
# #### Bộ phim nào có doanh thu cao nhất
# #### Bộ phim nào có thời gian chiếu lâu nhất

# %% [markdown]
# # Quality Issue 1:

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %% [markdown]
# ## Obvations
# Runtime 900 phút là quá thời gian so với một bộ phim và một bộ phim không thể nào có thời lượng chiếu là 0 phút.

# %% [markdown]
# # Quality Issue 2:

# %%
df.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64
